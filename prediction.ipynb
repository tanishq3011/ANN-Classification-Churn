# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
import pickle
import pandas as pd
import numpy as np

# %%
### Load the trained model, scaler pickle,onehot
### Load the trained model, scaler pickle, onehot
model = load_model('model.h5', compile=False)

## Load the encoder and scaler
with open('onehot_encoder_geography.pkl', 'rb') as f:
    onehot_encoder = pickle.load(f)

with open('label_encoder_gender.pkl', 'rb') as f:
    label_encoder_gender = pickle.load(f)

with open('scaler.pkl', 'rb') as f:
    scaler = pickle.load(f)

## Load the encoder and scaler
with open('onehot_encoder_geography.pkl', 'rb') as f:
    onehot_encoder = pickle.load(f)

with open('label_encoder_gender.pkl', 'rb') as f:
    label_encoder_gender = pickle.load(f)

with open('scaler.pkl', 'rb') as f:
    scaler = pickle.load(f)
# Out:
# c:\Users\Swati Saxena\OneDrive\Desktop\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Swati Saxena\OneDrive\Desktop\venv\Lib\site-packages\keras\src\saving\serialization_lib.py:737, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     736 try:
# --> 737     instance = cls.from_config(inner_config)
#     738 except TypeError as e:
#
# File c:\Users\Swati Saxena\OneDrive\Desktop\venv\Lib\site-packages\keras\src\losses\losses.py:45, in LossFunctionWrapper.from_config(cls, config)
#      44     config = serialization_lib.deserialize_keras_object(config)
# ---> 45 return cls(**config)
#
# TypeError: BinaryCrossentropy.__init__() got an unexpected keyword argument 'fn'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 ### Load the trained model, scaler pickle,onehot
# ----> 2 model = load_model('model.h5')
#       3
#       4 ## Load the encoder and scaler
#       5 with open('onehot_encoder_geography.pkl', 'rb') as f:
#
# File c:\Users\Swati Saxena\OneDrive\Desktop\venv\Lib\site-packages\keras\src\saving\saving_api.py:195, in load_model(filepath, custom_objects, compile, safe_mode)
#     188     return saving_lib.load_model(
#     189         filepath,
#     190         custom_objects=custom_objects,
#     191         compile=compile,
#     192         safe_mode=safe_mode,
#     193     )
#     194 if str(filepath).endswith((".h5", ".hdf5")):
# --> 195     return legacy_h5_format.load_model_from_hdf5(
#     196         filepath,
#     197         custom_objects=custom_objects,
#     198         compile=compile,
#     199         safe_mode=safe_mode,
#     200     )
#     202 # Check for Orbax checkpoint directory using utility function
#     203 if is_orbax_checkpoint(filepath):
#
# File c:\Users\Swati Saxena\OneDrive\Desktop\venv\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:163, in load_model_from_hdf5(filepath, custom_objects, compile, safe_mode)
#     159 training_config = json_utils.decode(training_config)
#     161 # Compile model.
#     162 model.compile(
# --> 163     **saving_utils.compile_args_from_training_config(
#     164         training_config, custom_objects
#     165     )
#     166 )
#     167 saving_utils.try_build_compiled_arguments(model)
#     169 # Set optimizer weights.
#
# File c:\Users\Swati Saxena\OneDrive\Desktop\venv\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:143, in compile_args_from_training_config(training_config, custom_objects)
#     141 loss_config = training_config.get("loss", None)
#     142 if loss_config is not None:
# --> 143     loss = _deserialize_nested_config(losses.deserialize, loss_config)
#     144     # Ensure backwards compatibility for losses in legacy H5 files
#     145     loss = _resolve_compile_arguments_compat(loss, loss_config, losses)
#
# File c:\Users\Swati Saxena\OneDrive\Desktop\venv\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:202, in _deserialize_nested_config(deserialize_fn, config)
#     200     return None
#     201 if _is_single_object(config):
# --> 202     return deserialize_fn(config)
#     203 elif isinstance(config, dict):
#     204     return {
#     205         k: _deserialize_nested_config(deserialize_fn, v)
#     206         for k, v in config.items()
#     207     }
#
# File c:\Users\Swati Saxena\OneDrive\Desktop\venv\Lib\site-packages\keras\src\losses\__init__.py:155, in deserialize(name, custom_objects)
#     142 @keras_export("keras.losses.deserialize")
#     143 def deserialize(name, custom_objects=None):
#     144     """Deserializes a serialized loss class/function instance.
#     145
#     146     Args:
#    (...)    153         A Keras `Loss` instance or a loss function.
#     154     """
# --> 155     return serialization_lib.deserialize_keras_object(
#     156         name,
#     157         module_objects=ALL_OBJECTS_DICT,
#     158         custom_objects=custom_objects,
#     159     )
#
# File c:\Users\Swati Saxena\OneDrive\Desktop\venv\Lib\site-packages\keras\src\saving\serialization_lib.py:600, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     593         if isinstance(module_objects[config], types.FunctionType):
#     594             return deserialize_keras_object(
#     595                 serialize_with_public_fn(
#     596                     module_objects[config], config, fn_module_name
#     597                 ),
#     598                 custom_objects=custom_objects,
#     599             )
# --> 600         return deserialize_keras_object(
#     601             serialize_with_public_class(
#     602                 module_objects[config], inner_config=inner_config
#     603             ),
#     604             custom_objects=custom_objects,
#     605         )
#     607 if isinstance(config, PLAIN_TYPES):
#     608     return config
#
# File c:\Users\Swati Saxena\OneDrive\Desktop\venv\Lib\site-packages\keras\src\saving\serialization_lib.py:739, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     737     instance = cls.from_config(inner_config)
#     738 except TypeError as e:
# --> 739     raise TypeError(
#     740         f"{cls} could not be deserialized properly. Please"
#     741         " ensure that components that are Python object"
#     742         " instances (layers, models, etc.) returned by"
#     743         " `get_config()` are explicitly deserialized in the"
#     744         " model's `from_config()` method."
#     745         f"\n\nconfig={config}.\n\nException encountered: {e}"
#     746     )
#     747 build_config = config.get("build_config", None)
#     748 if build_config and not instance.built:
#
# TypeError: <class 'keras.src.losses.losses.BinaryCrossentropy'> could not be deserialized properly. Please ensure that components that are Python object instances (layers, models, etc.) returned by `get_config()` are explicitly deserialized in the model's `from_config()` method.
#
# config={'module': 'keras.losses', 'class_name': 'BinaryCrossentropy', 'config': {'reduction': 'auto', 'name': 'binary_crossentropy', 'from_logits': False, 'label_smoothing': 0.0, 'axis': -1, 'fn': 'binary_crossentropy'}, 'registered_name': None}.
#
# Exception encountered: BinaryCrossentropy.__init__() got an unexpected keyword argument 'fn'

# %%
## Example Input data
input_data = {
    'CreditScore': 600,
    'Geography': 'France',
    'Gender': 'Male',
    'Age': 40,
    'Tenure': 3,
    'Balance': 60000,
    'NumOfProducts': 2,
    'HasCrCard': 1,
    'IsActiveMember': 1,
    'EstimatedSalary': 50000
}

# %%
## One-hot encode the Geography
geography_encoded = onehot_encoder.transform([[input_data['Geography']]]).toarray()
geography_df = pd.DataFrame(geography_encoded, columns=onehot_encoder.get_feature_names_out(['Geography']))
geography_df

# %%
input_df = pd.DataFrame([input_data])
input_df

# %%
## Combine one-hot encoded columns with input data
input_data = pd.concat([input_df.drop('Geography', axis=1), geography_df], axis=1)
input_data

# %%
## Encode categorical variable '
input_df['Gender'] = label_encoder_gender.transform(input_df['Gender'])
input_df

# %%
## Concatination one hot encoded
input_df=pd.concat([input_df.drop('Geography', axis=1), geography_df], axis=1)
input_df

# %%
## Scaling the input data
input_scaled = scaler.transform(input_df)
input_scaled

# %%
## Predict churn
prediction = model.predict(input_scaled)
prediction

# %%
prediction_probs = prediction[0][0]

# %%
prediction_probs

# %%
if prediction_probs > 0.5:
    print("The customer is likely to churn.")
else:
    print("The customer is unlikely to churn.")
